# %%
from aqi_trends import get_past_pollutant_trends

# Call the function
trends = get_past_pollutant_trends()

# Process or print the results
print(trends)
# Out:
# {'trends': {'30_days_past': {'Bangalore': {'hebbal,-bengaluru-air-quality': {'AQI': [{'date': '2024-12-14', 'value': 186, 'condition': 'Moderate', 'class': 'moderate'}, {'date': '2024-12-15', 'value': 184, 'condition': 'Moderate', 'class': 'moderate'}, {'date': '2024-12-16', 'value': 185, 'condition': 'Moderate', 'class': 'moderate'}, {'date': '2024-12-17', 'value': 186, 'condition': 'Moderate', 'class': 'moderate'}, {'date': '2024-12-18', 'value': 185, 'condition': 'Moderate', 'class': 'moderate'}, {'date': '2024-12-19', 'value': 186, 'condition': 'Moderate', 'class': 'moderate'}, {'date': '2024-12-20', 'value': 186, 'condition': 'Moderate', 'class': 'moderate'}, {'date': '2024-12-21', 'value': 186, 'condition': 'Moderate', 'class': 'moderate'}, {'date': '2024-12-22', 'value': 183, 'condition': 'Moderate', 'class': 'moderate'}, {'date': '2024-12-23', 'value': 185, 'condition': 'Moderate', 'class': 'moderate'}, {'date': '2024-12-24', 'value': 185, 'condition': 'Moderate', 'class': 'm
# ...

# %%
trends['trends']['30_days_past']['Bangalore']["hebbal,-bengaluru-air-quality"]
# Out:
# {'AQI': [{'date': '2024-12-14',
#    'value': 186,
#    'condition': 'Moderate',
#    'class': 'moderate'},
#   {'date': '2024-12-15',
#    'value': 184,
#    'condition': 'Moderate',
#    'class': 'moderate'},
#   {'date': '2024-12-16',
#    'value': 185,
#    'condition': 'Moderate',
#    'class': 'moderate'},
#   {'date': '2024-12-17',
#    'value': 186,
#    'condition': 'Moderate',
#    'class': 'moderate'},
#   {'date': '2024-12-18',
#    'value': 185,
#    'condition': 'Moderate',
#    'class': 'moderate'},
#   {'date': '2024-12-19',
#    'value': 186,
#    'condition': 'Moderate',
#    'class': 'moderate'},
#   {'date': '2024-12-20',
#    'value': 186,
#    'condition': 'Moderate',
#    'class': 'moderate'},
#   {'date': '2024-12-21',
#    'value': 186,
#    'condition': 'Moderate',
#    'class': 'moderate'},
#   {'date': '2024-12-22',
#    'value': 183,
#    'condition': 'Moderate',
#    'class': 'moderate'},
#   {'date': '2024-12-23',
#    'value': 185,
# ...

# %%
trends['trends']['7_days_past']['Bangalore']["hebbal,-bengaluru-air-quality"]
# Out:
# {'AQI': [{'date': '2025-01-06',
#    'value': 180,
#    'condition': 'Moderate',
#    'class': 'moderate'},
#   {'date': '2025-01-07',
#    'value': 181,
#    'condition': 'Moderate',
#    'class': 'moderate'},
#   {'date': '2025-01-08',
#    'value': 180,
#    'condition': 'Moderate',
#    'class': 'moderate'},
#   {'date': '2025-01-09',
#    'value': 180,
#    'condition': 'Moderate',
#    'class': 'moderate'},
#   {'date': '2025-01-10',
#    'value': 180,
#    'condition': 'Moderate',
#    'class': 'moderate'},
#   {'date': '2025-01-11',
#    'value': 181,
#    'condition': 'Moderate',
#    'class': 'moderate'},
#   {'date': '2025-01-12',
#    'value': 179,
#    'condition': 'Moderate',
#    'class': 'moderate'}],
#  'pm25': [{'date': '2025-01-06',
#    'value': 107,
#    'condition': None,
#    'class': None},
#   {'date': '2025-01-07', 'value': 107, 'condition': None, 'class': None},
#   {'date': '2025-01-08', 'value': 108, 'condition': None, 'class': None},
# ...
